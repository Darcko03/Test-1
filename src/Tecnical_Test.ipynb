# %%
# !pip install -U veryfi

# %%
import veryfi
import json
import re
import os

client_id = 'your_client_id'
client_secret = 'your_client_secret'
username = 'your_username'
api_key = 'your_password'

veryfi_client = veryfi.Client(client_id, client_secret, username, api_key)

def is_valid_document(response):
    # DEFINE THE PATTERNS. THESE 4 PARAMETERS WILL DETERMINE IF THE FILE HAS THE CORRECT FORMAT OR NOT AND ARE MANDATORY

    # COULD HAVE REQUESTED THE TOTAL VALUE OF THE INVOICE SO THAT THE DATA WAS A LITTLE MORE COMPLETE
    patterns = {
    'vendor_name': r'\w+',  # VENDOR NAME SHOULD BE AT LEAST ONE WORD. THIS IS ASSUMING THAT OTHER COMPANIES MAY HAVE THE SAME FORMAT; OTHERWISE, THE PATTERN SHOULD BE CHANGED TO r'^switch' AND APPLY re.IGNORECASE.
    'vendor_address': r'\w+',  # VENDOR ADDRESS SHOULD BE AT LEAST ONE WORD
    'invoice_number': r'\d+',  # INVOICE NUMBER SHOULD BE NUMERIC
    'date': r'\d{4}-\d{2}-\d{2}',  # DATE SHOULD BE IN YYYY-MM-DD FORMAT
    }

    # VERIFY THE PATTERNS
    vendor_name = response.get('vendor', {}).get('name', '')
    vendor_address = response.get('vendor', {}).get('address', '')
    invoice_number = response.get('invoice_number', '')
    date = response.get('date', '')

    if not isinstance(vendor_name, str) or not re.match(patterns['vendor_name'], vendor_name):
        return False
    if not isinstance(vendor_address, str) or not re.match(patterns['vendor_address'], vendor_address):
        return False
    if not isinstance(invoice_number, str) or not re.match(patterns['invoice_number'], invoice_number):
        return False
    if not isinstance(date, str) or not re.match(patterns['date'], date):
        return False

    return True

# EXTRACT THE DATA
def extract_information(response):

    ocr_text = response.get('ocr_text', '')

    # DEFINE THE FILE NAME FOR SAVING THE OCR TEXT
    base_name = os.path.splitext(file_name)[0]  # GET THE NAME WITHOUT EXTENSION
    txt_file_name = f'{base_name}.txt'  # ADD THE .txt EXTENSION
    txt_file_path = os.path.join(ocr_texts_folder, txt_file_name)  # FULL PATH TO SAVE

    # SAVE THE OCR TEXT TO THE FILE
    with open(txt_file_path, 'w', encoding='utf-8') as file:
        file.write(ocr_text)


    sku_pattern = r'\(([a-zA-Z0-9]{8})\)'
    extracted_data = {
        'vendor_name': response.get('vendor', {}).get('name'),
        'vendor_address': response.get('vendor', {}).get('address'),
        'bill_to_name': response.get('bill_to', {}).get('name'),
        'invoice_number': response.get('invoice_number'),
        'date': response.get('date'),
        'line_items': []
    }

    for item in response.get('line_items', []):
        description = item.get('description', '')

        #I ASSUMED THAT THE SKU WAS THE 8-CHARACTER ALPHANUMERIC DATA THAT ALWAYS COMES BETWEEN PARENTHESES IN THE DESCRIPTION. IF I WAS WRONG, I WOULD HAVE TO REPEAT THE PROCESS WITHOUT THE EXTRACTION STEP.
        result = re.search(sku_pattern, description)
        sku = result.group(1) if result else item.get('sku')

        line_item = {
            'sku': sku,
            'description': item.get('description'),
            'quantity': item.get('quantity'),
            'tax_rate': item.get('tax_rate'), # I DID NOT IDENTIFY ANY DATA THAT CAN BE TAKEN AS A TAX_RATE. THE MAIN REASON IS THAT I DID NOT FIND ANY DATA MARKED AS PERCENTAGE.
            'price': item.get('price'),
            'total': item.get('total')
        }
        extracted_data['line_items'].append(line_item)

    return extracted_data


folder = 'folder_with_the_files_to_extract_data_from'
ocr_texts_folder = 'folder_for_ocr_texts'
json_files_folder = 'folder_for_json_files'

# ENSURE THE FOLDERS EXIST
os.makedirs(ocr_texts_folder, exist_ok=True)
os.makedirs(json_files_folder, exist_ok=True)

for file_name in os.listdir(folder):
    full_path = os.path.join(folder, file_name)

    # EXTRACT THE OCR TEXT
    try:
        response = veryfi_client.process_document(full_path)

        # USE THE VALIDATION FUNCTION
        if is_valid_document(response):
            extracted_data = extract_information(response)

            # PRINT THE EXTRACTED DATA
            print(json.dumps(extracted_data, indent=4))

            # DEFINE THE FILE NAME FOR SAVING EXTRACTED DATA
            json_file_name = f'{base_name}_extracted.json'
            json_file_path = os.path.join(json_files_folder, json_file_name)

            # SAVE THE EXTRACTED DATA TO A JSON FILE
            with open(json_file_path, 'w', encoding='utf-8') as f:
                json.dump(extracted_data, f, indent=4)
        else:
            print(f"INVALID FORMAT FOR FILE: {file_name}")

    except Exception as e:
        print(f"ERROR PROCESSING FILE {file_name}: {e}")
# Out:
# ERROR PROCESSING FILE .ipynb_checkpoints: [Errno 21] Is a directory: 'pdfs/.ipynb_checkpoints'
# {
#     "vendor_name": "Switch, Ltd.",
#     "vendor_address": "PO Box 674592\nDallas, TX 75267-4592",
#     "bill_to_name": "Nu Life Health",
#     "invoice_number": "16005913",
#     "date": "2023-09-11 00:00:00",
#     "line_items": [
#         {
#             "sku": "U4M7QOSJ",
#             "description": "Carrier Taxes for Transport | 58 Gbps Wavelength Diverse between Sparks, OR 98765 and\nLasVegas, OR 56789 (ymEw7J) (U4M7QOSJ) (10/2023 Taxes) (10/2023)",
#             "quantity": 6016.09,
#             "tax_rate": null,
#             "price": -1781.87,
#             "total": -10719890.29
#         },
#         {
#             "sku": "X6HCHK1C",
#             "description": "Transport | 971 Gbps Fiber to wXv21fam (X6HCHK1C) (10/2023)",
#             "quantity": 3372.59,
#             "tax_rate": null,
#             "price": 3868.31,
#             "total": 13046223.62
#         },
#         {
#             "sku": "JTUKEGVE",
#             "description": "Carrier Taxes for Transport | 486 Gbps Wavelength Diverse between Hillsboro, NV 56789\nand Portland, NV 56789 (5FrLsxw) (JTUKEGVE) (05/2023 Taxes) (05/2023)",
#             "quantity": 3593.22,
#             "tax_rate": null,
#             "price": 4915.32,
#             "total": 17661826.13
#         },
#         {
#             "sku": "1OVAXL6A",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (8963157731) (01/2024|10 Gbps Fiber\nto dHrINDY (1OVAXL6A) (01/2024)",
#             "quantity": 1714.46,
#             "tax_rate": null,
#             "price": 1186.61,
#             "total": 2034395.38
#         },
#         {
#             "sku": "5HI7G80Q",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (6450580404) (01/2024|10 Gbps Fiber\nto l4AlFIIqmG (5HI7G80Q) (01/2024)",
#             "quantity": 3078.56,
#             "tax_rate": null,
#             "price": 5076.42,
#             "total": 15628063.56
#         },
#         {
#             "sku": "C2NXECIF",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (9818139719) (04/2023|10 Gbps Fiber\nto gGPS1 Ef6 (C2NXECIF) (04/2023)",
#             "quantity": 6480.38,
#             "tax_rate": null,
#             "price": 1340.91,
#             "total": 8689606.35
#         }
#     ]
# }
# {
#     "vendor_name": "Switch, Ltd.",
#     "vendor_address": "PO Box 674592\nDallas, TX 75267-4592",
#     "bill_to_name": "IncentX",
#     "invoice_number": "9230090",
#     "date": "2024-01-12 00:00:00",
#     "line_items": [
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 42 Gbps Fiber to pK2A19iL",
#             "quantity": 568.46,
#             "tax_rate": null,
#             "price": 8013.0,
#             "total": 4555069.98
#         },
#         {
#             "sku": "PVJTZ3D1",
#             "description": "Transport | 23 Gbps Fiber to oX0U2WYCkp (PVJTZ3D1) (02/2024)",
#             "quantity": 166.06,
#             "tax_rate": null,
#             "price": 1728.11,
#             "total": 286969.95
#         },
#         {
#             "sku": "0EYML836",
#             "description": "Transport | 88 Gbps Fiber to don0g Dz (0EYML836) (01/2024)",
#             "quantity": 15.25,
#             "tax_rate": null,
#             "price": 3714.52,
#             "total": 56646.43
#         },
#         {
#             "sku": "9HZIFE0Q",
#             "description": "Carrier Taxes for Transport | 75 Gbps Wavelength Diverse between Hillsboro, OR 12345\nand LasVegas, OR 12345 (ulmuh) (9HZIFE0Q) (07/2023 Taxes) (07/2023)",
#             "quantity": 844.8,
#             "tax_rate": null,
#             "price": 3596.97,
#             "total": 3038720.26
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 77 Gbps Fiber to Mk8Fdp",
#             "quantity": 4361.02,
#             "tax_rate": null,
#             "price": 4321.33,
#             "total": 18845406.56
#         },
#         {
#             "sku": "XHXSNF8V",
#             "description": "Transport | 671 Gbps Fiber to YdxQR4xvZ5 (XHXSNF8V) (05/2023)",
#             "quantity": 1484.48,
#             "tax_rate": null,
#             "price": 6007.97,
#             "total": 8918711.31
#         },
#         {
#             "sku": "7OIXBIDZ",
#             "description": "Transport | 52 Gbps Fiber to NWSedL9xP (7OIXBIDZ) (07/2023)",
#             "quantity": 3663.18,
#             "tax_rate": null,
#             "price": 2565.76,
#             "total": 9398840.72
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 89 Gbps Fiber to 5BIruFOtJ",
#             "quantity": 3.33,
#             "tax_rate": null,
#             "price": 341.44,
#             "total": 1137.0
#         },
#         {
#             "sku": "DEQRMH0M",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (8543422275) (12/2023|10 Gbps Fiber\nto trWn2BN (DEQRMH0M) (12/2023)",
#             "quantity": 4146.07,
#             "tax_rate": null,
#             "price": 5288.5,
#             "total": 21926491.2
#         },
#         {
#             "sku": null,
#             "description": "Special Partnership Discount (04/2023)",
#             "quantity": 1.0,
#             "tax_rate": null,
#             "price": -475.0,
#             "total": -475.0
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 319 Gbps Fiber to iHWs3",
#             "quantity": 2990.51,
#             "tax_rate": null,
#             "price": 3374.59,
#             "total": 10091745.14
#         },
#         {
#             "sku": "7BT0E5OA",
#             "description": "Transport | 276 Gbps Fiber to Qn9q48a3n (7BT0E5OA) (11/2023)",
#             "quantity": 5127.07,
#             "tax_rate": null,
#             "price": 6904.2,
#             "total": 35398316.69
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 88 Gbps Fiber to mtcBbWmz",
#             "quantity": 6768.74,
#             "tax_rate": null,
#             "price": -2670.59,
#             "total": -18076529.36
#         },
#         {
#             "sku": "FK1A0ZIF",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (3199207009) (09/2023 | 10 Gbps Fiber\nto CCbylY (FK1A0ZIF) (09/2023)",
#             "quantity": 2207.73,
#             "tax_rate": null,
#             "price": 4409.73,
#             "total": 9735493.21
#         },
#         {
#             "sku": "C7MDVWJC",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (7731249633) (12/2023|10 Gbps Fiber\nto MApm9 (C7MDVWJC) (12/2023)",
#             "quantity": 1876.56,
#             "tax_rate": null,
#             "price": 2077.12,
#             "total": 3897840.31
#         },
#         {
#             "sku": "RP61U2XG",
#             "description": "Transport | 60 Gbps Fiber to MdhOiwzT (RP61U2XG) (10/2023)",
#             "quantity": 7901.95,
#             "tax_rate": null,
#             "price": -306.54,
#             "total": -2422263.75
#         },
#         {
#             "sku": "4TY52SZK",
#             "description": "Carrier Taxes for Transport | 273 Gbps Wavelength Diverse between Plano, NV 56789 and\nLas Vegas, OR 98765 (jE7Z7Y) (4TY52SZK) (08/2023 Taxes) (08/2023)",
#             "quantity": 1091.68,
#             "tax_rate": null,
#             "price": 1658.71,
#             "total": 1810780.53
#         },
#         {
#             "sku": "DP1JX5HB",
#             "description": "Transport | 59 Gbps Fiber to hrl7lt35yF (DP1JX5HB) (01/2024)",
#             "quantity": 3490.92,
#             "tax_rate": null,
#             "price": 755.97,
#             "total": 2639030.79
#         },
#         {
#             "sku": "PTMBOJN6",
#             "description": "Transport | 202 Gbps Fiber to a2eCUfJT (PTMBOJN6) (10/2023)",
#             "quantity": 1171.92,
#             "tax_rate": null,
#             "price": 8020.4,
#             "total": 9399267.17
#         },
#         {
#             "sku": "HBRU88BL",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (2544203747) (11/2023 | 10 Gbps Fiber\nto tMEgg (HBRU88BL) (11/2023)",
#             "quantity": 45.84,
#             "tax_rate": null,
#             "price": 6802.02,
#             "total": 311804.6
#         },
#         {
#             "sku": "WUNGBVO9",
#             "description": "Transport | 899 Gbps Fiber to 4O3ksRx (WUNGBVO9) (04/2023)",
#             "quantity": -7761.79,
#             "tax_rate": null,
#             "price": 3392.35,
#             "total": -26330708.31
#         },
#         {
#             "sku": "H9EMYFGZ",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (2956599723) (07/2023 | 10 Gbps Fiber\nto MahuzuQ (H9EMYFGZ) (07/2023)",
#             "quantity": 7488.7,
#             "tax_rate": null,
#             "price": 219.26,
#             "total": 1641972.36
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 130 Gbps Fiber to YQ1enJePLb",
#             "quantity": 8163.68,
#             "tax_rate": null,
#             "price": 606.43,
#             "total": 4950700.46
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 932 Gbps Fiber to IEJhmuXqf",
#             "quantity": 392.72,
#             "tax_rate": null,
#             "price": 226.22,
#             "total": 88841.12
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 729 Gbps Fiber to za0vcLfl",
#             "quantity": 2545.2,
#             "tax_rate": null,
#             "price": 1189.11,
#             "total": 3026522.77
#         },
#         {
#             "sku": "2U6W4ERH",
#             "description": "Transport | 411 Gbps Fiber to Oi2uEg4ump (2U6W4ERH) (08/2023)",
#             "quantity": 4580.69,
#             "tax_rate": null,
#             "price": 6977.21,
#             "total": 31960436.07
#         },
#         {
#             "sku": null,
#             "description": "Special Partnership Discount (11/2023)",
#             "quantity": 8.0,
#             "tax_rate": null,
#             "price": -468.0,
#             "total": -3744.0
#         },
#         {
#             "sku": null,
#             "description": "Item Discount: Special Partnership Discount (01/2024)",
#             "quantity": 4.0,
#             "tax_rate": null,
#             "price": -373.0,
#             "total": -1492.0
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 59 Gbps Fiber to CaxR5QBTET",
#             "quantity": 3481.21,
#             "tax_rate": null,
#             "price": 2026.58,
#             "total": 7054950.56
#         },
#         {
#             "sku": "C7J2DAZW",
#             "description": "Transport | 785 Gbps Fiber to 9hcZA (C7J2DAZW) (02/2024)",
#             "quantity": 3966.14,
#             "tax_rate": null,
#             "price": 6967.88,
#             "total": 27635587.58
#         },
#         {
#             "sku": "RJ0MSXXY",
#             "description": "Transport | 96 Gbps Fiber to thKlZ (RJ0MSXXY) (03/2023)",
#             "quantity": 3827.74,
#             "tax_rate": null,
#             "price": 3802.01,
#             "total": 14553105.76
#         },
#         {
#             "sku": null,
#             "description": "Item Discount: One-Time Partnership Discount (12/2023)",
#             "quantity": 10.0,
#             "tax_rate": null,
#             "price": -443.0,
#             "total": -4430.0
#         },
#         {
#             "sku": "SVPNCJA7",
#             "description": "Transport | 692 Gbps Fiber to ClyH7W (SVPNCJA7) (01/2024)",
#             "quantity": 4493.65,
#             "tax_rate": null,
#             "price": 9544.65,
#             "total": 42890316.47
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 62 Gbps Fiber to TJuvx0i5T",
#             "quantity": 8377.3,
#             "tax_rate": null,
#             "price": 5632.47,
#             "total": 47184890.93
#         },
#         {
#             "sku": "L4ISW0IG",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (2916581229) (12/2023 | 10 Gbps Fiber\nto Y6vIUi7Fr4 (L4ISW0IG) (12/2023)",
#             "quantity": 88.91,
#             "tax_rate": null,
#             "price": 1295.84,
#             "total": 115213.13
#         },
#         {
#             "sku": "OGQRBEAM",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (3782168218) (02/2024|10 Gbps Fiber\nto Br9px3 (OGQRBEAM) (02/2024)",
#             "quantity": 3810.53,
#             "tax_rate": null,
#             "price": 288.49,
#             "total": 1099299.8
#         },
#         {
#             "sku": "1AJ6M5JQ",
#             "description": "Transport | 574 Gbps Fiber to nxSbT (1AJ6M5JQ) (02/2024)",
#             "quantity": 1868.64,
#             "tax_rate": null,
#             "price": 4414.16,
#             "total": 8248475.94
#         },
#         {
#             "sku": "UDYDHLA8",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (8870953009) (02/2024|10 Gbps Fiber\nto htM2xpl (UDYDHLA8) (02/2024)",
#             "quantity": 8677.67,
#             "tax_rate": null,
#             "price": 2688.3,
#             "total": 23328180.26
#         },
#         {
#             "sku": "0Y5DZ1V3",
#             "description": "Transport | 15 Gbps Fiber to gqKnwduT5 (0Y5DZ1V3) (03/2023)",
#             "quantity": 1507.81,
#             "tax_rate": null,
#             "price": 2592.63,
#             "total": 3909193.44
#         },
#         {
#             "sku": "UQ1ZH7NB",
#             "description": "Carrier Taxes for Transport | 085 Gbps Wavelength Diverse between Sparks, OR 56789 and\nPlano, OR 56789 (m58ex8CTHY) (UQ1ZH7NB) (08/2023 Taxes) (08/2023)",
#             "quantity": 7183.71,
#             "tax_rate": null,
#             "price": 5727.33,
#             "total": 41143477.79
#         },
#         {
#             "sku": "R0S1D72H",
#             "description": "Transport | 77 Gbps Fiber to YBeg RCU (R0S1D72H) (07/2023)",
#             "quantity": 1156.7,
#             "tax_rate": null,
#             "price": 5119.86,
#             "total": 5922142.06
#         },
#         {
#             "sku": "B4WA50YJ",
#             "description": "Transport | 448 Gbps Fiber to BBGNDSdV (B4WA50YJ) (09/2023)",
#             "quantity": 3582.36,
#             "tax_rate": null,
#             "price": 3481.91,
#             "total": 12473455.11
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 39 Gbps Fiber to XaZOzD",
#             "quantity": 4641.94,
#             "tax_rate": null,
#             "price": 2817.12,
#             "total": 13076902.01
#         },
#         {
#             "sku": "RPM9MOOM",
#             "description": "Carrier Taxes for Transport | 14 Gbps Wavelength Diverse between LasVegas, OR 56789\nand LasVegas, TX 12345 (6vBkqf5aon) (RPM9MOOM) (06/2023 Taxes) (06/2023)",
#             "quantity": 4791.27,
#             "tax_rate": null,
#             "price": 5691.57,
#             "total": 27269848.59
#         },
#         {
#             "sku": "FLCEOPU2",
#             "description": "Carrier Taxes for Transport | 05 Gbps Wavelength Diverse between Hillsboro, OR 12345\nand Plano, NV 12345 (DEzTH4) (FLCEOPU2) (06/2023 Taxes) (06/2023)",
#             "quantity": 4337.81,
#             "tax_rate": null,
#             "price": 3456.39,
#             "total": 14993163.11
#         },
#         {
#             "sku": "SKPR57R8",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (0456273488) (10/2023 | 10 Gbps Fiber\nto fV2ScDE57d (SKPR57R8) (10/2023)",
#             "quantity": 117.15,
#             "tax_rate": null,
#             "price": 4497.09,
#             "total": 526834.09
#         },
#         {
#             "sku": "M3GTIGSD",
#             "description": "Carrier Taxes for Transport | 64 Gbps Wavelength Diverse between LasVegas, OR 56789\nand Portland, NV 12345 (XxqBb8mDn8) (M3GTIGSD) (05/2023 Taxes) (05/2023)",
#             "quantity": 6125.63,
#             "tax_rate": null,
#             "price": 1010.69,
#             "total": 6191112.98
#         },
#         {
#             "sku": "6ZHSIGHM",
#             "description": "Carrier Taxes for Transport | 78 Gbps Wavelength Diverse between Sparks, OR 56789 and\nLasVegas, TX 12345 (7UvCeY) (6ZHSIGHM) (02/2024 Taxes) (02/2024)",
#             "quantity": 1297.2,
#             "tax_rate": null,
#             "price": -1597.66,
#             "total": -2072484.55
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 308 Gbps Fiber to 8aMBDWbD",
#             "quantity": 1608.12,
#             "tax_rate": null,
#             "price": 4279.77,
#             "total": 6882383.73
#         },
#         {
#             "sku": "KL31Q0CZ",
#             "description": "Transport | 731 Gbps Fiber to chH7Me2 (KL31Q0CZ) (03/2023)",
#             "quantity": 3691.55,
#             "tax_rate": null,
#             "price": 1997.56,
#             "total": 7374092.62
#         },
#         {
#             "sku": "22WU0DRJ",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (7052587572) (07/2023|10 Gbps Fiber\nto uvnE3C6LzL (22WU0DRJ) (07/2023)",
#             "quantity": 2043.37,
#             "tax_rate": null,
#             "price": 103.1,
#             "total": 210671.45
#         },
#         {
#             "sku": "I3G5Z5GY",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (1442439771) (11/2023|10 Gbps Fiber\nto NU67ydS (I3G5Z5GY) (11/2023)",
#             "quantity": 8142.13,
#             "tax_rate": null,
#             "price": 190.69,
#             "total": 1552622.77
#         }
#     ]
# }
# {
#     "vendor_name": "Switch, Ltd.",
#     "vendor_address": "PO Box 674592\nDallas, TX 75267-4592",
#     "bill_to_name": "Micro Merchant Systems, Inc.",
#     "invoice_number": "055205954",
#     "date": "2024-09-06 00:00:00",
#     "line_items": [
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 395 Gbps Fiber to AE9qC3",
#             "quantity": 579.1,
#             "tax_rate": null,
#             "price": 1750.3,
#             "total": 1013598.73
#         },
#         {
#             "sku": "02FDIWHG",
#             "description": "Transport | 71 Gbps Fiber to 04pBZ (02FDIWHG) (07/2023)",
#             "quantity": 5519.81,
#             "tax_rate": null,
#             "price": 5201.91,
#             "total": 28713554.84
#         },
#         {
#             "sku": "N0SBM4F4",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (0902986589) (03/2023 | 10 Gbps Fiber\nto TcUjOmG (N0SBM4F4) (03/2023)",
#             "quantity": 8360.15,
#             "tax_rate": null,
#             "price": 930.7,
#             "total": 7780791.61
#         },
#         {
#             "sku": "4UV4KE73",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (5659868303) (01/2024|10 Gbps Fiber\nto Ei9sXj (4UV4KE73) (01/2024)",
#             "quantity": 2983.62,
#             "tax_rate": null,
#             "price": 504.07,
#             "total": 1503953.33
#         },
#         {
#             "sku": "BF3EE94B",
#             "description": "Transport | 773 Gbps Fiber to 6YDZ35e (BF3EE94B) (06/2023)",
#             "quantity": 2999.36,
#             "tax_rate": null,
#             "price": 6741.52,
#             "total": 20220245.43
#         },
#         {
#             "sku": "6L0TQLHX",
#             "description": "Carrier Taxes for Transport | 522 Gbps Wavelength Diverse between Hillsboro, NV 98765\nand Plano, NV 56789 (NNn5Z) (6L0TQLHX) (08/2023 Taxes) (08/2023)",
#             "quantity": 4621.34,
#             "tax_rate": null,
#             "price": 2414.27,
#             "total": 11157162.52
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 272 Gbps Fiber to tvkSG1",
#             "quantity": 1602.87,
#             "tax_rate": null,
#             "price": null,
#             "total": 11720746.44
#         },
#         {
#             "sku": null,
#             "description": "Special Partnership Discount (10/2023)",
#             "quantity": -5.0,
#             "tax_rate": null,
#             "price": 8.0,
#             "total": -40.0
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 622 Gbps Fiber to WAMjxxiR7",
#             "quantity": 2505.75,
#             "tax_rate": null,
#             "price": 4015.41,
#             "total": 10061613.61
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 597 Gbps Fiber to hx6Lt0",
#             "quantity": 1900.69,
#             "tax_rate": null,
#             "price": 109.27,
#             "total": 207688.4
#         },
#         {
#             "sku": "NM9Q6IB5",
#             "description": "Carrier Taxes for Transport | 13 Gbps Wavelength Diverse between Plano, TX 12345 and\nPortland, TX 98765 (70dLMCF) (NM9Q6IB5) (11/2023 Taxes) (11/2023)",
#             "quantity": 1482.77,
#             "tax_rate": null,
#             "price": 3183.32,
#             "total": 4720131.4
#         },
#         {
#             "sku": "LXTKUOA9",
#             "description": "Transport | 783 Gbps Fiber to I5EKJZP (LXTKUOA9) (12/2023)",
#             "quantity": 5675.02,
#             "tax_rate": null,
#             "price": 4609.29,
#             "total": 26157812.94
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 807 Gbps Fiber to sSa8vygU",
#             "quantity": -7.0,
#             "tax_rate": null,
#             "price": 6844.22,
#             "total": -53106903.78
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 378 Gbps Fiber to sOaQHLg9h",
#             "quantity": 4502.76,
#             "tax_rate": null,
#             "price": 4076.66,
#             "total": 18356221.58
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 20 Gbps Fiber to r7aYvWyT",
#             "quantity": 4712.49,
#             "tax_rate": null,
#             "price": 2316.43,
#             "total": 10916153.21
#         },
#         {
#             "sku": "12D1B5JQ",
#             "description": "Carrier Taxes for Transport | 59 Gbps Wavelength Diverse between Sparks, NV 56789 and\nSparks, TX 12345 (ti9hB) (12D1B5JQ) (11/2023 Taxes) (11/2023)",
#             "quantity": 5924.8,
#             "tax_rate": null,
#             "price": 897.13,
#             "total": 5315315.82
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 846 Gbps Fiber to NZB1l",
#             "quantity": 425.3,
#             "tax_rate": null,
#             "price": 2070.07,
#             "total": 880400.77
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 64 Gbps Fiber to aPh6WzvK",
#             "quantity": 1872.81,
#             "tax_rate": null,
#             "price": 2338.93,
#             "total": 4380371.49
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 07 Gbps Fiber to Bjg8PJoqz",
#             "quantity": 7690.01,
#             "tax_rate": null,
#             "price": 1096.89,
#             "total": 8435095.07
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 472 Gbps Fiber to wpORN",
#             "quantity": 4240.57,
#             "tax_rate": null,
#             "price": 762.49,
#             "total": 3233392.22
#         },
#         {
#             "sku": "AI6GDFF3",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (1261588328) (07/2023|10 Gbps Fiber\nto Novz5 (AI6GDFF3) (07/2023)",
#             "quantity": 3680.84,
#             "tax_rate": null,
#             "price": 5424.26,
#             "total": 19965833.18
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 34 Gbps Fiber to atM4LwKE",
#             "quantity": 4790.42,
#             "tax_rate": null,
#             "price": 1674.95,
#             "total": 8023713.98
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 377 Gbps Fiber to yB89S",
#             "quantity": 434.13,
#             "tax_rate": null,
#             "price": 3631.73,
#             "total": 1576642.94
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 023 Gbps Fiber to unind",
#             "quantity": 721.3,
#             "tax_rate": null,
#             "price": 5897.78,
#             "total": 4254068.71
#         },
#         {
#             "sku": "M7G4G4ZI",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (9414549444) (07/2023 | 10 Gbps Fiber\nto HdiDj (M7G4G4ZI) (07/2023)",
#             "quantity": 2132.74,
#             "tax_rate": null,
#             "price": 3625.51,
#             "total": 7732270.2
#         },
#         {
#             "sku": "WMC164MN",
#             "description": "Transport | 986 Gbps Fiber to MMhmLMeXZc (WMC164MN) (12/2023)",
#             "quantity": 7705.52,
#             "tax_rate": null,
#             "price": 8644.71,
#             "total": 66611985.8
#         },
#         {
#             "sku": "P24S27MD",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (4134332881) (05/2023|10 Gbps Fiber\nto 0D9NDY3N0r (P24S27MD) (05/2023)",
#             "quantity": 2180.99,
#             "tax_rate": null,
#             "price": 5468.87,
#             "total": 11927550.78
#         },
#         {
#             "sku": "YJM37PUQ",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (2180276808) (02/2024|10 Gbps Fiber\nto RhiMxAj (YJM37PUQ) (02/2024)",
#             "quantity": 6947.59,
#             "tax_rate": null,
#             "price": 1289.78,
#             "total": 8960862.63
#         },
#         {
#             "sku": "D7C9I0CZ",
#             "description": "Carrier Taxes for Transport | 045 Gbps Wavelength Diverse between Plano, TX 98765 and\nPlano, OR 12345 (Rgb011jqs) (D7C9I0CZ) (10/2023 Taxes) (10/2023)",
#             "quantity": 3117.35,
#             "tax_rate": null,
#             "price": 7043.51,
#             "total": 21957085.9
#         }
#     ]
# }
# {
#     "vendor_name": "Switch, Ltd.",
#     "vendor_address": "PO Box 674592\nDallas, TX 75267-4592",
#     "bill_to_name": "Dataiku, Inc.",
#     "invoice_number": "699581195",
#     "date": "2023-11-18 00:00:00",
#     "line_items": [
#         {
#             "sku": "NLOBD16I",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (5741401765) (09/2023 | 10 Gbps Fiber\nto mQX5g4cY (NLOBD16I) (09/2023)",
#             "quantity": 4.7,
#             "tax_rate": null,
#             "price": 4354.28,
#             "total": 20465.12
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 690 Gbps Fiber to zuuBXKLZG",
#             "quantity": 353.21,
#             "tax_rate": null,
#             "price": 1251.12,
#             "total": 441908.1
#         },
#         {
#             "sku": "MK4CHGGT",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (7530228371) (09/2023 | 10 Gbps Fiber\nto EUtkqbSO (MK4CHGGT) (09/2023)",
#             "quantity": 4823.53,
#             "tax_rate": null,
#             "price": -1020.63,
#             "total": -4923039.42
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 907 Gbps Fiber to 5OGdqc",
#             "quantity": 475.5,
#             "tax_rate": null,
#             "price": 4764.54,
#             "total": 2265538.77
#         },
#         {
#             "sku": "H5TNRM9U",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (2746521855) (12/2023|10 Gbps Fiber\nto gC4kE3TTV (H5TNRM9U) (12/2023)",
#             "quantity": 347.46,
#             "tax_rate": null,
#             "price": 7885.71,
#             "total": 2739968.8
#         },
#         {
#             "sku": null,
#             "description": "Item Discount: Special Partnership Discount (02/2024)",
#             "quantity": 6.0,
#             "tax_rate": null,
#             "price": -43.0,
#             "total": -258.0
#         },
#         {
#             "sku": "E7JUMXRS",
#             "description": "Transport | 040 Gbps Fiber to 7nGIFCwq0H (E7JUMXRS) (10/2023)",
#             "quantity": 8278.13,
#             "tax_rate": null,
#             "price": 291.97,
#             "total": 2416965.62
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 75 Gbps Fiber to FmcmB9xEDO",
#             "quantity": 2264.96,
#             "tax_rate": null,
#             "price": 821.17,
#             "total": 1859917.2
#         },
#         {
#             "sku": "LENLZRKF",
#             "description": "Carrier Taxes for Transport | 11 Gbps Wavelength Diverse between Sparks, OR 12345 and\nLas Vegas, TX 98765 (OEM5fbta0) (LENLZRKF) (01/2024 Taxes) (01/2024)",
#             "quantity": 3213.97,
#             "tax_rate": null,
#             "price": 926.45,
#             "total": 2977582.51
#         },
#         {
#             "sku": "7Y5JG0WH",
#             "description": "Transport | 99 Gbps Fiber to Rcc3h (7Y5JG0WH) (05/2023)",
#             "quantity": -6362.73,
#             "tax_rate": null,
#             "price": 1585.94,
#             "total": -10090908.02
#         },
#         {
#             "sku": null,
#             "description": "Item Discount: One-Time Partnership Discount (02/2024)",
#             "quantity": -644.0,
#             "tax_rate": null,
#             "price": 7.0,
#             "total": -4508.0
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 87 Gbps Fiber to z78r91BUp5",
#             "quantity": 1259.8,
#             "tax_rate": null,
#             "price": 3262.72,
#             "total": 4110374.66
#         },
#         {
#             "sku": "MY1ACCE0",
#             "description": "Carrier Taxes for Transport | 585 Gbps Wavelength Diverse between Plano, TX 56789 and\nPortland, NV 98765 (mtWFAbmZzC) (MY1ACCE0) (11/2023 Taxes) (11/2023)",
#             "quantity": -3491.5,
#             "tax_rate": null,
#             "price": 2417.88,
#             "total": -8442028.02
#         },
#         {
#             "sku": "23C0Y1DE",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (2696286126) (02/2024|10 Gbps Fiber\nto tG8QL4dQ (23C0Y1DE) (02/2024)",
#             "quantity": 5033.07,
#             "tax_rate": null,
#             "price": 1301.47,
#             "total": 6550389.61
#         },
#         {
#             "sku": "UFKCJCVC",
#             "description": "Transport | 750 Gbps Fiber to PuXWMv (UFKCJCVC) (09/2023)",
#             "quantity": 343.99,
#             "tax_rate": null,
#             "price": 336.72,
#             "total": 115828.31
#         },
#         {
#             "sku": "87BSJFVS",
#             "description": "Carrier Taxes for Transport | 49 Gbps Wavelength Diverse between Hillsboro, OR 56789\nand Sparks, NV 98765 (ZgJlvoL) (87BSJFVS) (05/2023 Taxes) (05/2023)",
#             "quantity": 404.21,
#             "tax_rate": null,
#             "price": 2358.4,
#             "total": 953288.86
#         },
#         {
#             "sku": "PTDUAIUV",
#             "description": "Carrier Taxes for Transport | 84 Gbps Wavelength Diverse between Plano, OR 56789 and\nPlano, NV 98765 (jz5iOqPFU) (PTDUAIUV) (03/2023 Taxes) (03/2023)",
#             "quantity": 1799.45,
#             "tax_rate": null,
#             "price": 8253.72,
#             "total": 14852156.45
#         },
#         {
#             "sku": "WCHCP0RF",
#             "description": "Carrier Taxes for Transport | 21 Gbps Wavelength Diverse between LasVegas, OR 12345\nand Plano, NV 98765 (Bppcbo9) (WCHCP0RF) (06/2023 Taxes) (06/2023)",
#             "quantity": 663.92,
#             "tax_rate": null,
#             "price": 3339.71,
#             "total": 2217300.26
#         },
#         {
#             "sku": "9X6N196Q",
#             "description": "Carrier Taxes for Transport | 31 Gbps Wavelength Diverse between Plano, OR 12345 and\nPlano, TX 56789 (rMJ08fdV3) (9X6N196Q) (07/2023 Taxes) (07/2023)",
#             "quantity": 4926.7,
#             "tax_rate": null,
#             "price": 3575.35,
#             "total": 17614676.84
#         },
#         {
#             "sku": "5MFVE9BL",
#             "description": "Carrier Taxes for Transport | 511 Gbps Wavelength Diverse between Portland, OR 12345\nand Sparks, NV 12345 (0RTbu) (5MFVE9BL) (03/2023 Taxes) (03/2023)",
#             "quantity": 5759.41,
#             "tax_rate": null,
#             "price": 4204.68,
#             "total": 24216476.04
#         },
#         {
#             "sku": null,
#             "description": "Item Discount: Special Partnership Discount (02/2024)",
#             "quantity": 7.0,
#             "tax_rate": null,
#             "price": -579.0,
#             "total": -8106.0
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 590 Gbps Fiber to 79Q5cvUF",
#             "quantity": 973.17,
#             "tax_rate": null,
#             "price": 5969.51,
#             "total": 5809348.05
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 74 Gbps Fiber to dyen",
#             "quantity": 1545.03,
#             "tax_rate": null,
#             "price": 2800.07,
#             "total": 4326192.15
#         },
#         {
#             "sku": "X47VYARP",
#             "description": "Transport | 719 Gbps Fiber to 0RxCo6EF3 (X47VYARP) (08/2023)",
#             "quantity": 6874.59,
#             "tax_rate": null,
#             "price": 6356.55,
#             "total": 43698675.06
#         },
#         {
#             "sku": null,
#             "description": "Installation of Cross Connect | 99 Gbps Fiber to jUdIwc",
#             "quantity": 170.75,
#             "tax_rate": null,
#             "price": 6832.01,
#             "total": 1166565.71
#         },
#         {
#             "sku": "4MVQGWYE",
#             "description": "Transport | 506 Gbps Fiber to 49SxN6 (4MVQGWYE) (09/2023)",
#             "quantity": 2932.72,
#             "tax_rate": null,
#             "price": 8720.18,
#             "total": 25573846.29
#         },
#         {
#             "sku": "X17YWJQN",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (4634995248) (09/2023 | 10 Gbps Fiber\nto 976sq4 (X17YWJQN) (09/2023)",
#             "quantity": 3380.0,
#             "tax_rate": null,
#             "price": 979.67,
#             "total": 3311284.6
#         }
#     ]
# }
# {
#     "vendor_name": "switch",
#     "vendor_address": "PO Box 674592\nDallas, TX 75267-4592",
#     "bill_to_name": "Toni Hackel",
#     "invoice_number": "1556267",
#     "date": "2023-09-22 00:00:00",
#     "line_items": [
#         {
#             "sku": "YSPG4VFH",
#             "description": "Transport | Switch Fiber Pair (Intra-campus) | Pairs (4419693704) (04/2023|10 Gbps Fiber\nto HOEpyb (YSPG4VFH) (04/2023)",
#             "quantity": 2912.98,
#             "tax_rate": null,
#             "price": 934.09,
#             "total": 2720985.49
#         },
#         {
#             "sku": "NJYM5MQP",
#             "description": "Carrier Taxes for Transport | 230 Gbps Wavelength Diverse between Sparks, OR 56789 and\nPlano, NV 98765 (SNpTfT) (NJYM5MQP) (07/2023 Taxes) (07/2023)",
#             "quantity": 3500.87,
#             "tax_rate": null,
#             "price": 6229.33,
#             "total": 21808074.52
#         },
#         {
#             "sku": null,
#             "description": "Special Partnership Discount (03/2023)",
#             "quantity": 8.0,
#             "tax_rate": null,
#             "price": -561.0,
#             "total": -8976.0
#         },
#         {
#             "sku": null,
#             "description": "Item Discount: Special Partnership Discount (11/2023)",
#             "quantity": 8.0,
#             "tax_rate": null,
#             "price": -296.0,
#             "total": -2368.0
#         },
#         {
#             "sku": "L0KSKNCB",
#             "description": "Transport | 82 Gbps Fiber to YDDTJOrnuW (L0KSKNCB) (01/2024)",
#             "quantity": 5607.34,
#             "tax_rate": null,
#             "price": 656.07,
#             "total": 3678807.55
#         },
#         {
#             "sku": "8D3PKG77",
#             "description": "Carrier Taxes for Transport | 45 Gbps Wavelength Diverse between Hillsboro, NV 98765\nand Portland, TX 56789 (a488ZH) (8D3PKG77) (05/2023 Taxes) (05/2023)",
#             "quantity": 7128.95,
#             "tax_rate": null,
#             "price": 3949.46,
#             "total": 28155502.87
#         },
#         {
#             "sku": "5EE7PIWY",
#             "description": "Transport | 97 Gbps Fiber to 3XMOyFdB (5EE7PIWY) (02/2024)",
#             "quantity": 1918.01,
#             "tax_rate": null,
#             "price": 942.71,
#             "total": 1808127.21
#         }
#     ]
# }
# INVALID FORMAT FOR FILE: Bill.pdf
